# %% [markdown]
# # P08_Modelling Readiness 2 (Student Version)
#
# **Version:** v1
#
#
# **Expected lesson duration:** 2 hours

# %% [markdown]
# ## Recall from previous practical (P07)
#
# You prepared X and y correctly.

# %% [markdown]
# ## Current practical learning outcome
#
# Split, encode, scale in proper order.

# %% [markdown]
# ## ICA / timed task link
#
# Workflow order matters for marks and correctness.

# %% [markdown]
# ## Goals
#
# 1. Train-test split
# 2. Encode categorical features
# 3. Scale numeric features
# 4. Check final output

# %% [markdown]
# ## Lets Load

# %%
import pandas as pd
import numpy as np
import os
from google.colab import drive

# %%
# Try it yourself
# from sklearn.model_selection import train_test_split
# from sklearn.preprocessing import StandardScaler

# %%
# Try it yourself
# Mount Drive, change to /content/drive/MyDrive/DSES, then show os.getcwd()

# %%
# Try it yourself
# Load hiring_data.csv and create X,y

# %%
# Try it yourself
# Split into train and test with stratify=y

# %%
# Try it yourself
# Find cat_cols and num_cols

# %%
# Try it yourself
# Encode categorical columns using mapping from X_train

# %%
# Try it yourself
# Scale numeric columns: fit_transform on train, transform on test

# %%
# Try it yourself
# Check missing values and class counts in train/test

# %% [markdown]
# ## Qn / Ans reflection
#
# 1. Qn: Why avoid scaling before split?
# Ans:
#
# 2. Qn: What is one encoding issue in test data?
# Ans:
#
# 3. Qn: What checks confirm model-readiness?
# Ans:

# %% [markdown]
# ## Wrap up
#
# P09: build a simple regression model and interpret R² carefully.
