# %% [markdown]
# # P05_Data Exploration 1 (Student Version)
#
# **Expected lesson duration:** 2 hours

# %% [markdown]
# ## Recall from previous practical (P04)
#
# You used EDA to observe unusual patterns.

# %% [markdown]
# ## Current practical learning outcome
#
# Check quality issues and decide what not to use.

# %% [markdown]
# ## ICA / timed task link
#
# Clean obvious issues early to avoid later mistakes.

# %% [markdown]
# ## Goals
#
# 1. Duplicates and missing values
# 2. Category checks
# 3. Identifier/sensitive column checks
# 4. Basic masking

# %% [markdown]
# ## Lets Load

# %%
import pandas as pd
import numpy as np
import os
from google.colab import drive

# %%
# Try it yourself
# Mount Drive, change to /content/drive/MyDrive/DSES, then show os.getcwd()

# %%
# Try it yourself
# Read hiring_data.csv and show head()

# %%
# Try it yourself
# Check duplicates and missing values

# %%
# Try it yourself
# Show value_counts for race and hired

# %%
# Try it yourself
# Find identifier-like columns (id/name/email/phone keywords)

# %%
# Try it yourself
# Create masked copy for name

# %%
# Try it yourself
# Create df_model by dropping id-like columns

# %%
# Try it yourself
# Convert clearly invalid numeric values to NaN (if any)

# %% [markdown]
# ## Qn / Ans reflection
#
# 1. Qn: Why avoid identifier columns in modelling?
# Ans:
#
# 2. Qn: Why is masking important?
# Ans:
#
# 3. Qn: What quality checks did you run first?
# Ans:

# %% [markdown]
# ## Wrap up
#
# Next practical: deeper EDA and transformations only when needed.
