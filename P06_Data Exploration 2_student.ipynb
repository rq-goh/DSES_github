# %% [markdown]
# # P06_Data Exploration 2 (Student Version)
#
# **Expected lesson duration:** 2 hours

# %% [markdown]
# ## Recall from previous practical (P05)
#
# You cleaned obvious issues and filtered unsuitable columns.

# %% [markdown]
# ## Current practical learning outcome
#
# Explore distribution shape and transform only with reason.

# %% [markdown]
# ## ICA / timed task link
#
# Simple transformation can help, but only when justified.

# %% [markdown]
# ## Goals
#
# 1. Check skewness
# 2. Compare raw vs transformed variable
# 3. Build one engineered feature

# %% [markdown]
# ## Lets Load

# %%
import pandas as pd
import numpy as np
import os
from google.colab import drive

# %%
# Try it yourself
# import matplotlib.pyplot as plt and seaborn as sns

# %%
# Try it yourself
# Mount Drive, change to /content/drive/MyDrive/DSES, then show os.getcwd()

# %%
# Try it yourself
# Load hiring_data.csv and display head()

# %%
# Try it yourself
# Describe age, gpa, years_of_exp

# %%
# Try it yourself
# Check skewness

# %%
# Try it yourself
# Plot years_of_exp raw histogram and log1p histogram

# %%
# Try it yourself
# Scatterplot gpa vs years_of_exp with hired as hue

# %%
# Try it yourself
# Create feature gpa_x_exp

# %% [markdown]
# ## Qn / Ans reflection
#
# 1. Qn: Which variable looked skewed?
# Ans:
#
# 2. Qn: Why did you apply log1p?
# Ans:
#
# 3. Qn: What is one engineered feature you created and why?
# Ans:

# %% [markdown]
# ## Wrap up
#
# Next: prepare features and target for modelling.
