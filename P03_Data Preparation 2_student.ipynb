# %% [markdown]
# # P03_Data Preparation 2 (Student Version)
#
# **Expected lesson duration:** 2 hours

# %% [markdown]
# ## Recall from previous practical (P02)
#
# You controlled rows/columns using indexing and slicing.

# %% [markdown]
# ## Current practical learning outcome
#
# Today you inspect missing values and compare imputation methods.

# %% [markdown]
# ## ICA / timed task link
#
# Do not fill missing values blindly in timed tasks.

# %% [markdown]
# ## Goals
#
# 1. Find missing values
# 2. Separate numeric and categorical columns
# 3. Try mean/median/mode/KNN

# %% [markdown]
# ## Lets Load

# %%
import pandas as pd
import numpy as np
import os
from google.colab import drive

# %%
# Try it yourself
# import matplotlib.pyplot as plt, seaborn as sns
# from sklearn.impute import SimpleImputer, KNNImputer

# %%
# Try it yourself
# Mount Drive, change to /content/drive/MyDrive/DSES, then show os.getcwd()

# %%
# Try it yourself
# Read loan_data.csv and show head()

# %%
# Try it yourself
# Show shape, dtypes, and missing value count

# %%
# Try it yourself
# Create num_cols and cat_cols using select_dtypes

# %%
# Try it yourself
# Create copies and apply SimpleImputer(mean, median, most_frequent)

# %%
# Try it yourself
# Apply KNNImputer on numeric columns

# %%
# Try it yourself
# Plot histogram comparison before vs after imputation for loan_amt

# %% [markdown]
# ## Qn / Ans reflection
#
# 1. Qn: Which column had missing values?
# Ans:
#
# 2. Qn: Why not use mean for categorical columns?
# Ans:
#
# 3. Qn: Why compare imputation methods?
# Ans:

# %% [markdown]
# ## Wrap up
#
# Next practical is EDA: use the right plot for the right variable.
