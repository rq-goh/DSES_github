# %% [markdown]
# ![IIT_original.png](attachment:IIT_original.png)
# ## <center>  Data Science Essentials (CIA2C14)</center>
# ### <center>  Practical 1 : Google Colab </center>

# %% [markdown]
# # 1. Setup Google Drive, create a new folder "DSES"
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# #2. Drag drop your files in.
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # 3. You can double click to run the specific ipynb file.

# %% [markdown]
# # 4. Connect to enable runtime
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # 5. You can upload dataset to a temporary folder.
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # 6. You can get the file path to read by right clicking it.
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### 1.1 Working Directory
# It is a good practice to have all our data files related to the same problem statement in the same folder, and read these files into our Jupyter Notebook just with simple codes. To begin, we must know how to access that folder

# %%
from google.colab import drive
drive.mount('/content/drive')

#select account > allow > continue > continue

# %%
#import the pandas module
import pandas as pd
#Using files, 6th icon on left toolbar, navigate to drinks.csv file location.
#right click and copy path
#run follow code to read the drinks.csv into a DataFrame
?
#display the dataframe
from IPython.display import Markdown, display
?
#check out the 'interactive table' and 'suggest chart' as blue buttons beside the displayed table.

# %% [markdown]
# # <font color=red> NOTE to students. Suggested graphs and GenAI generated code will NOT be marked in DSES.

# %%
from matplotlib import pyplot as plt
?

# %% [markdown]
# #### 1.2.1	Get current working directory
# The OS module in python provides functions for interacting with the operating system. Use the getcwd() function.

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Try obtaining your own current working directory</b>
# </div>

# %%
import os
?

# %% [markdown]
# Try to upload the csv file into the content folder (not google drive yet).
#
# Restart Google Colab
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# #### 1.2.2	Change the working directory
# If you wish to navigate away from the current directory and access some files in another directory, performing the following: <br><font color='blue'>
# os.chdir("Your New Directory")</font>

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Try changing to another directory (folder) and list the files in it</b>
# </div>

# %%
from google.colab import drive
drive.mount('/content/drive')

#select account > allow > continue > continue

# %% [markdown]
# The csv file should be missing from Files. The csv within Google Drive should still be present. This function is very useful, to ensure permanence of items. Useful for storing partially processed data / models, so that we can continue where we left off on our assignments / projects across multiple sessions.

# %%
import os
#make the change
?

# %%
?

# %%
?

# %% [markdown]
# #### 1.3.1	Read the local csv file
# - If you are already in the correct directory containing your local file, simply perform the following.
# - Otherwise, you would need to include the path in the string for filename.
# - Using the read_csv() function, read the file. *Note the ‘_’ not ‘.’
# - As this file is a csv file, we force Pandas to read the data into respective cells, delimited by comma.
# - If your csv file already contain headers, you don’t have to include the header argument.

# %% [markdown]
# #### 1.3.2 View your data

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Load your recently downloaded drinks.csv into a dataframe. <br>
#     Print out the first few rows of your dataframe. </b>
# </div>

# %%
import pandas as pd
#read the drinks.csv
#dataframe is named drinks_data
drinks_data=pd.read_csv("drinks.csv", delimiter=",") # csv=comma separated value
drinks_data.head()
#drinks_data.tail()

# %% [markdown]
# ### 1.3.3 Identify and understand your data

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Follow your tutor to use some syntax to find out more about your dataframe.</b>
# </div>

# %%
?

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Find the summary statistics of data using ?.</b>
# </div>

# %%
?

# %% [markdown]
# What do you observe:

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Modify the code to view the statistics of a particular column, say ‘continent’</b>
# </div>

# %%
?

# %% [markdown]
# What is the most frequent continent?

# %%
?

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Print the mean (average) beer serving per-person per-country</b>
# </div>

# %%
?

# %% [markdown]
# What is the lowest beer serving and the highest beer serving recorded:
# ?

# %%
?

# %%
?

# %% [markdown]
# ## 2.	Selecting and getting a subset of the DataFrame

# %% [markdown]
# ### 2.1	Select some columns
# As we move deeper into the Data Science concepts, such as Exploratory Data Analysis (EDA), we may delve into just a few features (columns) that we are interested to measure. Thus, let us learn how to get a subset of data from the full set, as it is easier and faster to manipulate a small DataFrame.

# %% [markdown]
# #### 2.1.1 By name
# - Using [ ] for accessing data, simply key in the names of the columns as strings.
# - Recall that a DataFrame is two-dimensional, thus you need to have a nested [ ].

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Access all the rows for the attributes 'country' and 'continent' </b>
# </div>

# %%
#Select using the column names
?

# %% [markdown]
# #### 2.1.2 By index
# - Using iloc() and [ ], we can key in the index of the columns we are interested to select.
# - Recall indexing in Python starts from 0.
# - To include all rows, use : .

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Display the same subsetted dataframe using iloc</b>
# </div>

# %%
#Select using index
# iloc= index location
?

# %%
?

# %% [markdown]
# #### 2.2 Select some rows
# - Also by using iloc() and [ ], we can choose some rows, aka observations or instances. However note the order of indexing and that the last row to be included is one increment smaller than index used.

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Display the 11th to 16th row of the main dataframe</b>
# </div>

# %%
?

# %%
#select rows based on condition, drinks_data where continent == AS
?

# %%
#select rows based on condition, 'beer_servings' >= 50
?

# %%
?
