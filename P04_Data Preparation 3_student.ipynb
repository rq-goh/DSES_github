# %% [markdown]
# # P04_Data Preparation 3 (Student Version)
#
# **Expected lesson duration:** 2 hours

# %% [markdown]
# ## Recall from previous practical (P03)
#
# You inspected missing values and compared imputation choices.

# %% [markdown]
# ## Current practical learning outcome
#
# Use EDA plots correctly and connect plots to decisions.

# %% [markdown]
# ## ICA / timed task link
#
# Plot with purpose, not just for decoration.

# %% [markdown]
# ## Goals
#
# 1. Summarize numeric and categorical columns
# 2. Build univariate and bivariate plots
# 3. Propose one engineered feature

# %% [markdown]
# ## Lets Load

# %%
import pandas as pd
import numpy as np
import os
from google.colab import drive

# %%
# Try it yourself
# import matplotlib.pyplot as plt and seaborn as sns

# %%
# Try it yourself
# Mount Drive, change to /content/drive/MyDrive/DSES, then show os.getcwd()

# %%
# Try it yourself
# Load Cars93.csv and display head()

# %%
# Try it yourself
# Run describe(include='all') and isnull().sum()

# %%
# Try it yourself
# Separate numeric and categorical columns

# %%
# Try it yourself
# Histplot for Price

# %%
# Try it yourself
# Boxplot for Horsepower

# %%
# Try it yourself
# Countplot for Type

# %%
# Try it yourself
# Scatterplot: Horsepower vs Price with hue Origin

# %%
# Try it yourself
# Crosstab Type vs Origin

# %%
# Try it yourself
# Correlation heatmap for numeric columns

# %%
# Try it yourself
# Create hp_per_mpg_city = Horsepower / MPG.city

# %% [markdown]
# ## Qn / Ans reflection
#
# 1. Qn: Which plot best shows distribution for one numeric variable?
# Ans:
#
# 2. Qn: What did you observe from Horsepower vs Price?
# Ans:
#
# 3. Qn: Why can engineered features help later modelling?
# Ans:

# %% [markdown]
# ## Wrap up
#
# Next: data exploration with quality checks, duplicates, suspicious values, and masking.
