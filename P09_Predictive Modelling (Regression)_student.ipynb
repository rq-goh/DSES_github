# %% [markdown]
# # P09_Predictive Modelling (Regression) (Student Version)
#
# **Expected lesson duration:** 2 hours

# %% [markdown]
# ## Recall from previous practical (P08)
#
# You prepared clean train/test inputs.

# %% [markdown]
# ## Current practical learning outcome
#
# Fit and evaluate a basic regression model.

# %% [markdown]
# ## ICA / timed task link
#
# Regression tasks follow a clear timed workflow.

# %% [markdown]
# ## Goals
#
# 1. Pick continuous target
# 2. Fit model
# 3. Predict
# 4. Interpret R²

# %% [markdown]
# ## Lets Load

# %%
import pandas as pd
import numpy as np
import os
from google.colab import drive

# %%
# Try it yourself
# Import train_test_split, LinearRegression, r2_score

# %%
# Try it yourself
# Mount Drive, change to /content/drive/MyDrive/DSES, then show os.getcwd()

# %%
# Try it yourself
# Load Cars93.csv, pick feature columns and target='Price'

# %%
# Try it yourself
# Train-test split

# %%
# Try it yourself
# Fit LinearRegression

# %%
# Try it yourself
# Predict on train/test and compute R²

# %%
# Try it yourself
# Display model coefficients

# %% [markdown]
# ## Qn / Ans reflection
#
# 1. Qn: Why is this a regression task?
# Ans:
#
# 2. Qn: What do train and test R² tell you?
# Ans:
#
# 3. Qn: Why should we not rely on R² only?
# Ans:

# %% [markdown]
# ## Wrap up
#
# Next is classification (closer to ICA focus).
