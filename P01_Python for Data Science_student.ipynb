# %% [markdown]
# # P01 - Python for Data Science (Student Version)
#
# **Expected lesson duration:** 2 hours
#
# Today we practice the startup routine you must be able to do fast in ICA.

# %% [markdown]
# ## Why this practical matters
#
# If your setup is slow, you lose easy marks.
#
# From this point onwards, use this same startup flow in each practical.

# %% [markdown]
# ## Lesson flow (2 hours)
#
# - **0:00 - 0:15** Intro
# - **0:15 - 0:35** Colab setup
# - **0:35 - 1:05** Load dataset
# - **1:05 - 1:35** Practice inspection
# - **1:35 - 1:55** Qn / Ans reflections
# - **1:55 - 2:00** Wrap up

# %% [markdown]
# ## Learning outcomes
#
# By the end, you should be able to:
#
# 1. Mount Drive
# 2. Set working directory
# 3. Load `drinks.csv`
# 4. Use `head()`, `info()`, `describe()`
# 5. Select basic rows and columns

# %% [markdown]
# ## ICA / timed task link
#
# In timed tasks, first 5 minutes matter a lot.
#
# If setup is correct, the rest becomes easier.

# %% [markdown]
# ## Step 1 - Lets Load imports

# %%
import pandas as pd
import numpy as np
import os
from google.colab import drive

# %% [markdown]
# ## Step 2 - Mount Drive and set folder

# %%
# Try it yourself
# 1) Mount Google Drive
# 2) Change directory to /content/drive/MyDrive/DSES
# 3) Show current working directory

# %% [markdown]
# ## Step 3 - Read drinks.csv

# %%
# Try it yourself
# Create a dataframe called df by reading drinks.csv
# Then display df

# %% [markdown]
# ## Step 4 - Quick inspection

# %%
# Try it yourself
# Show first 5 rows

# %%
# Try it yourself
# Run info()

# %%
# Try it yourself
# Run describe()

# %% [markdown]
# ## Step 5 - Basic column and row access

# %%
# Try it yourself
# Show all column names

# %%
# Try it yourself
# Show first 10 country values

# %%
# Try it yourself
# Show country, beer_servings, wine_servings for first 10 rows

# %%
# Try it yourself
# Show row at index 0 with iloc

# %%
# Try it yourself
# Show rows 0 to 4 and columns 0 to 3 with iloc

# %% [markdown]
# ## Qn / Ans reflection block
#
# Write your answers below each question:
#
# 1. Qn: How many rows and columns are in this dataset?
#    Ans:
#
# 2. Qn: Which columns are numeric and which are categorical?
#    Ans:
#
# 3. Qn: What did you observe from `describe()`?
#    Ans:
#
# 4. Qn: Which continent labels appear in this data?
#    Ans:

# %% [markdown]
# ## Mini practice
#
# Complete these quickly:
#
# 1. Show first 3 rows
# 2. Show only `country` and `total_litres_of_pure_alcohol`
# 3. Show rows 10 to 20 using `iloc`
# 4. Show all rows but only columns index 1 to 3

# %%
# Try it yourself

# %%
# Try it yourself

# %%
# Try it yourself

# %%
# Try it yourself

# %% [markdown]
# ## Wrap up
#
# Good work. If this startup routine is smooth, P02 will be much easier.
