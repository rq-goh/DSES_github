# %% [markdown]
# # P01 - Python for Data Science (Tutor Version)
#
# **Expected lesson duration:** 2 hours
#
# In this practical, we build the starter routine for all later practicals. Keep it simple and do it right.

# %% [markdown]
# ## Why this practical matters
#
# If students cannot mount Drive, set the folder, and load data quickly, they lose time in ICA and timed data tasks.
#
# From this point onwards, this setup becomes your default start.

# %% [markdown]
# ## Lesson flow (2 hours)
#
# - **0:00 - 0:15** Quick intro + what we need to do in ICA
# - **0:15 - 0:35** Google Colab setup and working directory
# - **0:35 - 1:05** Load `drinks.csv` and inspect quickly
# - **1:05 - 1:35** Practice row/column selection (`head`, columns, `iloc`)
# - **1:35 - 1:55** Qn / Ans reflection discussion
# - **1:55 - 2:00** Wrap up + what comes in P02

# %% [markdown]
# ## Learning outcomes
#
# By the end of this practical, students should be able to:
#
# 1. Mount Google Drive in Colab
# 2. Set the correct working directory
# 3. Load `drinks.csv` using pandas
# 4. Inspect dataset structure with `head()`, `info()`, and `describe()`
# 5. Select simple rows and columns without confusion

# %% [markdown]
# ## ICA / timed task link
#
# ICA is time-tight. If setup is slow, marks are lost early.
#
# This same startup routine is also useful for hackerrank-style data tasks where you must quickly load and inspect data before solving.

# %% [markdown]
# ## Step 1 - Lets Load imports

# %%
import pandas as pd
import numpy as np
import os
from google.colab import drive

# %% [markdown]
# ## Step 2 - Mount Drive and set folder

# %%
drive.mount('/content/drive')
os.chdir('/content/drive/MyDrive/DSES')
os.getcwd()

# %% [markdown]
# ## Step 3 - Read the dataset

# %%
df = pd.read_csv('drinks.csv')
df

# %% [markdown]
# ## Step 4 - Quick inspection

# %%
df.head()

# %%
df.info()

# %%
df.describe()

# %% [markdown]
# ## Step 5 - Basic column and row access

# %%
df.columns

# %%
df['country'].head(10)

# %%
df[['country','beer_servings','wine_servings']].head(10)

# %%
df.iloc[0]

# %%
df.iloc[0:5, 0:4]

# %% [markdown]
# ## Guided observations (Tutor Answers)
#
# ### Qn 1
# **Qn:** How many rows and columns are in this dataset?
#
# **Ans:** `drinks.csv` has **193 rows** and **6 columns**.
#
# ### Qn 2
# **Qn:** Which columns are numeric and which are categorical?
#
# **Ans:**
# - **Categorical:** `country`, `continent`
# - **Numeric:** `beer_servings`, `spirit_servings`, `wine_servings`, `total_litres_of_pure_alcohol`
#
# ### Qn 3
# **Qn:** What did you observe from quick summary stats?
#
# **Ans:**
# - Beer servings mean is about **106.16**, with a max of **376**
# - Spirit servings mean is about **80.99**, with a max of **438**
# - Wine servings is more right-skewed (median **8**, mean **49.45**)
# - Total litres mean is around **4.72**, max **14.4**
#
# ### Qn 4
# **Qn:** Which continent labels appear in this file?
#
# **Ans:** `AF`, `EU`, `AS`, `NA`, `OC`, `SA`.

# %% [markdown]
# ## Mini practice prompt
#
# Try these quickly with students:
#
# 1. Show first 3 rows only
# 2. Show only `country` and `total_litres_of_pure_alcohol`
# 3. Show rows 10 to 20 using `iloc`
# 4. Show all rows but only columns index 1 to 3

# %%
# Example answers for mini practice
df.head(3)

# %%
df[['country','total_litres_of_pure_alcohol']].head()

# %%
df.iloc[10:21]

# %%
df.iloc[:,1:4].head()

# %% [markdown]
# ## Wrap up
#
# Today is about startup routine and quick inspection.
#
# In P02, we move from just loading data to controlling rows and columns more confidently using indexing and slicing.
