# %% [markdown]
# # P10_Predictive Modelling (Classification) (Student Version)
#
# **Version:** v1
#
#
# **Expected lesson duration:** 2 hours

# %% [markdown]
# ## Recall from previous practical (P08)
#
# You built train/test-ready inputs.

# %% [markdown]
# ## Current practical learning outcome
#
# Run a full basic classification workflow.

# %% [markdown]
# ## ICA / timed task link
#
# This practical is closest to expected ICA model workflow.

# %% [markdown]
# ## Goals
#
# 1. Logistic regression fit
# 2. Predict classes
# 3. Accuracy, precision, recall
# 4. Confusion matrix interpretation

# %% [markdown]
# ## Lets Load

# %%
import pandas as pd
import numpy as np
import os
from google.colab import drive

# %%
# Try it yourself
# Import train_test_split, StandardScaler, LogisticRegression, confusion matrix + metrics

# %%
# Try it yourself
# Mount Drive, change to /content/drive/MyDrive/DSES, then show os.getcwd()

# %%
# Try it yourself
# Load hiring_data.csv and create X,y (drop name)

# %%
# Try it yourself
# Encode categorical columns

# %%
# Try it yourself
# Split train/test with stratify=y

# %%
# Try it yourself
# Scale numeric columns using train-fitted scaler

# %%
# Try it yourself
# Fit logistic regression and predict

# %%
# Try it yourself
# Compute accuracy, precision, recall

# %%
# Try it yourself
# Display confusion matrix

# %% [markdown]
# ## Qn / Ans reflection
#
# 1. Qn: Why can accuracy be misleading here?
# Ans:
#
# 2. Qn: What does precision mean in your own words?
# Ans:
#
# 3. Qn: What does recall mean in your own words?
# Ans:

# %% [markdown]
# ## Wrap up
#
# Next practical is the P11 mock test rehearsal.
