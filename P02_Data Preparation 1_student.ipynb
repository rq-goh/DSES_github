# %% [markdown]
# # P02 - Data Preparation 1 (Student Version)
#
# **Version:** v1
#
#
# **Expected lesson duration: 2 hours**

# %% [markdown]
# ## Recall from previous practical (P01)
#
# You already practiced setup, reading csv, and quick inspection with `head()`, `info()`, `describe()`.

# %% [markdown]
# ## Current practical learning outcome
#
# Today you will control rows and columns confidently using slicing and filtering.

# %% [markdown]
# ## ICA / timed interview / hackerrank-style link
#
# In timed tasks, you must inspect the correct part of the dataframe quickly.

# %% [markdown]
# ## 2-hour lesson flow
#
# - 0:00-0:15 recall
# - 0:15-0:30 setup/load
# - 0:30-1:00 row/column controls
# - 1:00-1:30 iloc/loc drills
# - 1:30-1:50 timed mini task
# - 1:50-2:00 reflection

# %% [markdown]
# ## Lets Load

# %%
import pandas as pd
import numpy as np
import os
from google.colab import drive

# %%
# Try it yourself
# Mount Drive
# Change directory to /content/drive/MyDrive/DSES
# Show current working directory

# %% [markdown]
# ## Step 1 - Load drinks.csv

# %%
# Try it yourself
# Read drinks.csv into df
# Show first 5 rows

# %%
# Try it yourself
# Show shape, columns, and dtypes

# %% [markdown]
# ## Step 2 - Column selection

# %%
# Try it yourself
# Select single column: country

# %%
# Try it yourself
# Select multiple columns: country, beer_servings, wine_servings

# %%
# Try it yourself
# Compare df['country'] vs df[['country']]

# %% [markdown]
# ## Step 3 - iloc practice

# %%
# Try it yourself
# Show row 0

# %%
# Try it yourself
# Show first 5 rows

# %%
# Try it yourself
# Show rows 10 to 20 and first 4 columns

# %%
# Try it yourself
# Show all rows but columns index 1 to 3

# %% [markdown]
# ## Step 4 - loc + condition practice

# %%
# Try it yourself
# Countries where beer_servings > 200

# %%
# Try it yourself
# Countries with wine_servings > 100 and continent == 'EU'

# %%
# Try it yourself
# Countries with total_litres_of_pure_alcohol >= 10

# %% [markdown]
# ## Step 5 - Quick profiling

# %%
# Try it yourself
# value_counts for continent

# %%
# Try it yourself
# describe for numeric drinking columns

# %%
# Try it yourself
# top 10 countries by beer_servings

# %% [markdown]
# ## Timed mini-task (15-20 mins)
#
# 1. Show last 8 rows
# 2. Show rows 20-35 and first 4 columns
# 3. Asia countries with spirit_servings > 100
# 4. Top 5 by total litres
# 5. Count countries with beer_servings == 0

# %%
# Try it yourself

# %% [markdown]
# ## Qn / Ans reflection
#
# 1. Qn: What is the shape of drinks.csv?
# Ans:
#
# 2. Qn: Which columns are categorical?
# Ans:
#
# 3. Qn: What is one difference between iloc and loc?
# Ans:
#
# 4. Qn: Why is this practical important before P03?
# Ans:

# %% [markdown]
# ## Wrap up
#
# If you can target rows/columns confidently, missing-value handling in P03 becomes much easier.
