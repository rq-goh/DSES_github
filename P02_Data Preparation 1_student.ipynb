# %% [markdown]
# # P02_Data Preparation 1 (Student Version)
#
# **Expected lesson duration:** 2 hours

# %% [markdown]
# ## Recall from previous practical (P01)
#
# You already learned setup and quick inspection routine.

# %% [markdown]
# ## Current practical learning outcome
#
# Today you practice row/column control using indexing and slicing.

# %% [markdown]
# ## ICA / timed task link
#
# If you can inspect the right rows/columns fast, you save time and avoid mistakes.

# %% [markdown]
# ## Goals
#
# 1. Use `.shape`, `.columns`, `.dtypes`
# 2. Practice `.iloc` and `.loc`
# 3. Filter and select columns correctly

# %% [markdown]
# ## Lets Load

# %%
import pandas as pd
import numpy as np
import os
from google.colab import drive

# %%
# Try it yourself
# Mount Drive, change to /content/drive/MyDrive/DSES, then show os.getcwd()

# %% [markdown]
# ## Build a simple dataframe first

# %%
# Try it yourself
# Create df_simple with columns: student_id, name, score, attendance
# Display it

# %%
# Try it yourself
# Show shape, columns, and dtypes

# %% [markdown]
# ## Indexing and slicing

# %%
# Try it yourself
# Show first row with iloc

# %%
# Try it yourself
# Show rows index 1 to 3 and first 3 columns

# %%
# Try it yourself
# Filter students with score >= 80

# %%
# Try it yourself
# Select only name and score columns

# %% [markdown]
# ## Bridge to drinks.csv

# %%
# Try it yourself
# Read drinks.csv as df and show head()

# %%
# Try it yourself
# Show first 10 rows and first 4 columns using iloc

# %%
# Try it yourself
# Show countries with beer_servings > 200 and include continent

# %% [markdown]
# ## Qn / Ans reflection
#
# 1. Qn: Why use slicing instead of viewing full table?
# Ans:
#
# 2. Qn: `.iloc` vs `.loc` difference?
# Ans:
#
# 3. Qn: How does this help in ICA?
# Ans:

# %% [markdown]
# ## Wrap up
#
# Good. In P03 we inspect missing values and decide imputation methods.
