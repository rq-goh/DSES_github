# %% [markdown]
# # P11_Mock Test (Student Version)
#
# **Version:** v1
#
#
# **Expected lesson duration:** 2 hours

# %% [markdown]
# ## Recall from previous practical (P10)
#
# You learned classification evaluation beyond accuracy.

# %% [markdown]
# ## Current practical learning outcome
#
# Practice end-to-end pipeline under time pressure.

# %% [markdown]
# ## ICA / timed task link
#
# This is a rehearsal format for ICA.

# %% [markdown]
# ## Mock test goals
#
# 1. Setup quickly
# 2. Clean obvious issues
# 3. Select target/X
# 4. Split + model
# 5. Evaluate + justify

# %% [markdown]
# ## Time plan (2 hours)
#
# - 0:00-0:15 setup/load
# - 0:15-0:40 quality checks
# - 0:40-1:05 quick EDA
# - 1:05-1:35 preprocessing/split
# - 1:35-1:55 modelling/evaluation
# - 1:55-2:00 short write-up

# %% [markdown]
# ## Lets Load

# %%
import pandas as pd
import numpy as np
import os
from google.colab import drive

# %%
# Try it yourself
# Import plotting + sklearn tools needed for classification workflow

# %%
# Try it yourself
# Mount Drive, change to /content/drive/MyDrive/DSES, then show os.getcwd()

# %%
# Try it yourself
# Load hiring_data.csv and show quick checks (shape, duplicates, missing)

# %%
# Try it yourself
# Define target='hired' and build X by dropping name + target

# %%
# Try it yourself
# Encode categorical columns

# %%
# Try it yourself
# Split train/test and scale numeric columns

# %%
# Try it yourself
# Fit LogisticRegression and predict

# %%
# Try it yourself
# Compute accuracy, precision, recall

# %%
# Try it yourself
# Plot confusion matrix

# %% [markdown]
# ## Qn / Ans reflection
#
# 1. Qn: Which steps are non-negotiable in timed test?
# Ans:
#
# 2. Qn: What class imbalance did you notice?
# Ans:
#
# 3. Qn: What would you explain in 3 lines to justify your workflow?
# Ans:

# %% [markdown]
# ## Final mock note
#
# Focus on correctness and clarity, not quantity of methods.
