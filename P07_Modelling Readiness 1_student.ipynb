# %% [markdown]
# # P07_Modelling Readiness 1 (Student Version)
#
# **Expected lesson duration:** 2 hours

# %% [markdown]
# ## Recall from previous practical (P06)
#
# You evaluated variable usefulness before modelling.

# %% [markdown]
# ## Current practical learning outcome
#
# Build clean `X` and `y` with sensible column choices.

# %% [markdown]
# ## ICA / timed task link
#
# Wrong target/predictor setup causes major mark loss.

# %% [markdown]
# ## Goals
#
# 1. Define target
# 2. Remove id-like columns
# 3. Build X and y
# 4. Check target counts

# %% [markdown]
# ## Lets Load

# %%
import pandas as pd
import numpy as np
import os
from google.colab import drive

# %%
# Try it yourself
# Mount Drive, change to /content/drive/MyDrive/DSES, then show os.getcwd()

# %%
# Try it yourself
# Load hiring_data.csv and inspect columns

# %%
# Try it yourself
# Set target='hired' and find id-like columns

# %%
# Try it yourself
# Build X and y

# %%
# Try it yourself
# Check X dtypes and split numeric vs categorical columns

# %%
# Try it yourself
# Show y.value_counts()

# %% [markdown]
# ## Qn / Ans reflection
#
# 1. Qn: Why remove identifier columns?
# Ans:
#
# 2. Qn: Which columns are numeric predictors?
# Ans:
#
# 3. Qn: Is y balanced? Why does that matter?
# Ans:

# %% [markdown]
# ## Wrap up
#
# Next: split, encode, and scale correctly.
